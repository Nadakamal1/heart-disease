# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df= pd.read_csv('../data/heart_disease.csv')

# %% [markdown]
# **understanding data set**

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# **Data Preprocessing**

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 723

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns:
    unique_count = df[col].nunique()
    print(f"{col} : {unique_count}")
# Out:
# age : 41
# sex : 2
# cp : 4
# trestbps : 49
# chol : 152
# fbs : 2
# restecg : 3
# thalach : 91
# exang : 2
# oldpeak : 40
# slope : 3
# ca : 5
# thal : 4
# target : 2

# %%
df.head(25)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# 12   34    0   1       118   210    0        1      192      0      0.7
# 13   51    1   0       140   298    0        1      122      1      4.2
# 14   52    1   0       128   204    1        1      156      1      1.0
# 16   51    0   2       140   308    0        0      142      0      1.5
# 17   54    1   0       124   266    0        0      109      1      2.2
# 18   50    0   1       120   244    0        1      162      0      1.1
# 19   58    1   2       140   211    1        0      165      0      0.0
# 20   60    1   2       140   185    0        0      155      0      3.0
# 21   67    0   0       106   223    0        1      142      0      0.3
# 22   45    1   0       104   208    0        0      148      1      3.0
# 23   63    0   2       135   252    0        0      172      0      0.0
# 24   42    0   2       120   209    0        1      173      0      0.0
# 25   61    0   0       145   307    0        0      146      1      1.0
#
#     slope  ca  thal  target
# 0       2   2     3       0
# 1       0   0     3       0
# 2       0   0     3       0
# 3       2   1     3       0
# 4       1   3     2       0
# 5       1   0     2       1
# 6       0   3     1       0
# 7       1   1     3       0
# 8       2   0     3       0
# 9       1   2     2       0
# 10      1   0     2       1
# 11      1   0     3       0
# 12      2   0     2       1
# 13      1   3     3       0
# 14      1   0     0       0
# 16      2   1     2       1
# 17      1   1     3       0
# 18      2   0     2       1
# 19      2   0     2       1
# 20      1   0     2       0
# 21      2   2     2       1
# 22      1   0     2       1
# 23      2   0     2       1
# 24      1   0     2       1
# 25      1   0     3       0

# %%
# Separate features and target
# X = df.drop("target", axis=1)
# y = df["target"]

# Continuous columns to scale


import joblib


continuous_cols = ["age", "trestbps", "chol", "thalach", "oldpeak"]

scaler = StandardScaler()
df[continuous_cols] = scaler.fit_transform(df[continuous_cols])
joblib.dump(scaler, "../models/scaler.pkl")
df.head(25)
# Out:
#          age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  -0.267966    1   0 -0.376556 -0.667728    0        1  0.806035      0
# 1  -0.157260    1   0  0.478910 -0.841918    1        0  0.237495      1
# 2   1.724733    1   0  0.764066 -1.403197    0        1 -1.074521      1
# 3   0.728383    1   0  0.935159 -0.841918    0        1  0.499898      0
# 4   0.839089    0   0  0.364848  0.919336    1        1 -1.905464      0
# 5   0.396267    0   0 -1.802334  0.029032    0        0 -1.205722      0
# 6   0.396267    1   0 -1.003898  1.383842    0        2 -0.418513      0
# 7   0.064151    1   0  1.619532  0.822564    0        0 -0.199843      1
# 8  -0.932199    1   0 -0.661712  0.048386    0        0 -0.243577      0
# 9  -0.046555    1   0 -0.547650  0.764500    0        0 -1.468126      1
# 10  1.835438    0   0 -1.117961 -1.887058    0        1 -1.074521      0
# 11 -1.264315    0   0  0.022661  1.828995    1        0 -0.593448      1
# 12 -2.260664    0   1 -0.775774 -0.706437    0        1  1.855648      0
# 13 -0.378671    1   0  0.478910  0.996754    0        1 -1.205722      1
# 14 -0.267966    1   0 -0.205463 -0.822564    1        1  0.281229      1
# 16 -0.378671    0   2  0.478910  1.190298    0        0 -0.331045      0
# 17 -0.046555    1   0 -0.433587  0.377412    0        0 -1.774263      1
# 18 -0.489377    0   1 -0.661712 -0.048386    0        1  0.543632      0
# 19  0.396267    1   2  0.478910 -0.687083    1        0  0.674834      0
# 20  0.617678    1   2  0.478910 -1.190298    0        0  0.237495      0
# 21  1.392616    0   0 -1.460147 -0.454829    0        1 -0.331045      0
# 22 -1.042904    1   0 -1.574210 -0.745146    0        0 -0.068642      1
# 23  0.949794    0   2  0.193755  0.106449    0        0  0.980971      0
# 24 -1.375021    0   2 -0.661712 -0.725791    0        1  1.024705      0
# 25  0.728383    0   0  0.764066  1.170944    0        0 -0.156110      1
#
#      oldpeak  slope  ca  thal  target
# 0  -0.037124      2   2     3       0
# 1   1.773958      0   0     3       0
# 2   1.342748      0   0     3       0
# 3  -0.899544      2   1     3       0
# 4   0.739054      1   3     2       0
# 5  -0.037124      1   0     2       1
# 6   2.895104      0   3     1       0
# 7  -0.209608      1   1     3       0
# 8  -0.209608      2   0     3       0
# 9   1.860200      1   2     2       0
# 10  0.480328      1   0     2       1
# 11  1.687716      1   0     3       0
# 12 -0.295850      2   0     2       1
# 13  2.722620      1   3     3       0
# 14 -0.037124      1   0     0       0
# 16  0.394086      2   1     2       1
# 17  0.997780      1   1     3       0
# 18  0.049118      2   0     2       1
# 19 -0.899544      2   0     2       1
# 20  1.687716      1   0     2       0
# 21 -0.640818      2   2     2       1
# 22  1.687716      1   0     2       1
# 23 -0.899544      2   0     2       1
# 24 -0.899544      1   0     2       1
# 25 -0.037124      1   0     3       0

# %% [markdown]
# **Exploraty Data Analysis**

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(15, 10), bins=20, edgecolor="black")
plt.suptitle("Histograms of Features", fontsize=16)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(15, 10))

for i, col in enumerate(["age", "trestbps", "chol", "thalach", "oldpeak"]):
    plt.subplot(2, 3, i+1)
    sns.boxplot(x="target", y=col, data=df, palette="Set2")
    plt.title(f"Boxplot of {col} by Target")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1928\3297241630.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="target", y=col, data=df, palette="Set2")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1928\3297241630.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="target", y=col, data=df, palette="Set2")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1928\3297241630.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="target", y=col, data=df, palette="Set2")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1928\3297241630.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="target", y=col, data=df, palette="Set2")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1928\3297241630.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="target", y=col, data=df, palette="Set2")

# %%
# Save cleaned data
df.to_csv("../data/heart_disease_cleaned.csv", index=False)
